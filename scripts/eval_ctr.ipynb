# %% [markdown]
# # Dementia Evaluation
#
# This notebook is used to evaluate the trained models.

# %%
import os, random, time, numpy as np, pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import losses, optimizers, metrics
from tensorflow.keras import Input, Model, layers, callbacks, regularizers, models
from jarvis.train import custom, datasets, params
from jarvis.train.client import Client
from jarvis.utils.general import gpus, overload, tools as jtools
from jarvis.utils.display import imshow
from sklearn.metrics import classification_report

# %%
@overload(Client)
def preprocess(self, arrays, **kwargs):
    
    # --- Extract pre-calculated whole exam mu/sd and normalize
    arrays['xs']['dat'] = (arrays['xs']['dat'] - kwargs['row']['mu']) / kwargs['row']['sd']
    
    # --- Scale to 0/1 using 5/95 percentiles
    lower = np.percentile(arrays['xs']['dat'], 1)
    upper = np.percentile(arrays['xs']['dat'], 99)
    arrays['xs']['dat'] = arrays['xs']['dat'].clip(min=lower, max=upper)
    arrays['xs']['dat'] = (arrays['xs']['dat'] - lower) / (upper - lower)
    
    return arrays

# %%
# --- Load contrastive model
model = models.load_model("/home/mmorelan/proj/dementia/train/raw/26/01/model.hdf5", compile=False)

# --- Extract autoencoder model from contrastive model
autoencoder = model.layers[3]

# %%
model.layers[3].summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 96, 160, 160 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 96, 160, 160, 112         input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 96, 160, 160, 0           conv3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 96, 160, 160, 16          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 48, 80, 80, 8 872         batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 48, 80, 80, 8 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 48, 80, 80, 8 32          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 48, 80, 80, 8 1736        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 48, 80, 80, 8 0           conv3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 48, 80, 80, 8 32          leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 24, 40, 40, 1 3472        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 24, 40, 40, 1 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 24, 40, 40, 1 64          leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 24, 40, 40, 1 6928        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 24, 40, 40, 1 0           conv3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 24, 40, 40, 1 64          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 12, 20, 20, 3 13856       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 12, 20, 20, 3 0           conv3d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 12, 20, 20, 3 128         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 12, 20, 20, 3 27680       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 12, 20, 20, 3 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 12, 20, 20, 3 128         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 6, 10, 10, 64 55360       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 6, 10, 10, 64 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 6, 10, 10, 64 256         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 6, 10, 10, 64 110656      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 6, 10, 10, 64 0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 6, 10, 10, 64 256         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 3, 5, 5, 128) 221312      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 3, 5, 5, 128) 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 3, 5, 5, 128) 512         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 3, 5, 5, 128) 442496      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 3, 5, 5, 128) 0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 3, 5, 5, 128) 512         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 3, 5, 5, 4)   516         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 300)          0           conv3d_11[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           9632        flatten[0][0]
# __________________________________________________________________________________________________
# ctr (Dense)                     (None, 8)            264         dense_1[0][0]
# __________________________________________________________________________________________________
# enc (Dense)                     (None, 1)            33          dense_1[0][0]
# ==================================================================================================
# Total params: 896,925
# Trainable params: 895,925
# Non-trainable params: 1,000
# __________________________________________________________________________________________________

# %%
# --- Initialize client
AD_CLIENT_PATH = '/home/mmorelan/proj/dementia/yml/client-3d-raw_AD_AV45_only.yml'
CN_CLIENT_PATH = '/home/mmorelan/proj/dementia/yml/client-3d-raw_CN_AV45_only.yml'

client_AD = Client(AD_CLIENT_PATH, configs={'batch': {'fold': 0}})
client_CN = Client(CN_CLIENT_PATH, configs={'batch': {'fold': 0}})

# %%
# --- Create validation generator
test_AD_train, test_AD_valid = client_AD.create_generators(test=True)
test_CN_train, test_CN_valid = client_CN.create_generators(test=True)

# %%
# --- Aggregate all examples
xs = []
ys = []

for x, y in test_AD_valid:
    xs.append(x['dat'][0])
    ys.append(y['lbl'][0])
    
for x, y in test_CN_valid:
    xs.append(x['dat'][0])
    ys.append(y['lbl'][0])
    
xs = np.array(xs)
ys = np.array(ys)
# Out:
# [ 2021-09-28 21:38:46 ] [====================] 100.000% : Iterating | 000249

# %%
def visualize_reconstruction(index):
    x = xs[np.newaxis, index, :]
    y = ys[np.newaxis, index, :]
    
    logits = autoencoder.predict(x)
    
    # Visualize reconstruction
    dec_logits = logits['dec']
    dec_logits[0, 0, 0, 1] = 1.0
    dec_logits[0, 0, 0, 0] = 0.0
    print(dec_logits.min(), dec_logits.max())
    imshow(dec_logits, figsize=(12, 12))
    plt.show()
    
    # Visualize ground truth
    print(x.min(), x.max())
    imshow(x, figsize=(12, 12))
    plt.show()

# %%
#05/01
visualize_reconstruction(0)
# Out:
# 0.0 1.0
# 0.0 1.0

# %%
logits = autoencoder.predict(xs)

# %%
def classification_metrics(logits, threshold=0.5):
    # --- Calculate metrics
    if type(logits) is dict:
        enc_logits = logits['enc']

    # --- Binarize probability predictions according to threshold
    pred = enc_logits
    pred[pred < threshold] = 0
    pred[pred >= threshold] = 1

    df = pd.DataFrame()
    df['pred'] = np.squeeze(pred)
    df['true'] = np.squeeze(ys)
    df['corr'] = df['pred'] == df['true']

    print("Accuracy:", df['corr'].mean())
    print(classification_report(y_true=df['true'], y_pred=df['pred']))

# %%
classification_metrics(logits)
# Out:
# Accuracy: 0.23666666666666666
#               precision    recall  f1-score   support
#
#            0       0.95      0.08      0.15       249
#            1       0.18      0.98      0.30        51
#
#     accuracy                           0.24       300
#    macro avg       0.57      0.53      0.23       300
# weighted avg       0.82      0.24      0.18       300

# %%
classification_metrics(logits)
# Out:
# Accuracy: 0.8566666666666667
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91       249
#            1       0.56      0.71      0.63        51
#
#     accuracy                           0.86       300
#    macro avg       0.75      0.80      0.77       300
# weighted avg       0.87      0.86      0.86       300

# %%
classification_metrics(logits)
# Out:
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.90       249
#            1       0.54      0.80      0.65        51
#
#     accuracy                           0.85       300
#    macro avg       0.75      0.83      0.78       300
# weighted avg       0.88      0.85      0.86       300

# %%
classification_metrics(logits)
# Out:
# Accuracy: 0.8566666666666667
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       249
#            1       0.56      0.69      0.62        51
#
#     accuracy                           0.86       300
#    macro avg       0.75      0.79      0.77       300
# weighted avg       0.87      0.86      0.86       300

# %%
classification_metrics(logits)
# Out:
# Accuracy: 0.86
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91       249
#            1       0.57      0.73      0.64        51
#
#     accuracy                           0.86       300
#    macro avg       0.75      0.81      0.78       300
# weighted avg       0.88      0.86      0.87       300
